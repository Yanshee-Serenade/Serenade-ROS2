# %%
from ros_api import TrackingDataClient

# 初始化客户端
client = TrackingDataClient(server_ip='127.0.0.1', port=51121)

# 连接服务器并解析数据
if client.connect_to_server():
    # 关键优化：主动发送请求数据（解决服务器recv阻塞）
    client.send_request()
    parsed_data = client.parse_byte_stream()
    if parsed_data:
        client.display_results(parsed_data)
    client.close_connection()
else:
    print("=== [Client] Exit due to connection failure ===")
# Out:
# === [Client Init] Connecting to 127.0.0.1:51121... ===
# === [Client Init] Connected successfully! Cost 0.21 ms ===
# === [Client Request] Sending request: b'GET_TRACKING_DATA' (17 bytes) ===
# === [Parse Stream] Starting byte stream parsing... ===
# === [Recv Data] Intrinsics: Waiting for 32 bytes... ===
# === [Recv Data] Intrinsics: Received 32/32 bytes (100.0%) ===
# === [Recv Data] Intrinsics: Received complete! 32 bytes, cost 42.28 ms ===
# === [Parse Stream] 1. Intrinsics parsed: fx=503.64, fy=502.17, cx=312.57, cy=244.44 ===
# === [Recv Data] Service Success: Waiting for 1 bytes... ===
# === [Recv Data] Service Success: Received 1/1 bytes (100.0%) ===
# === [Recv Data] Service Success: Received complete! 1 bytes, cost 0.04 ms ===
# === [Parse Stream] 2. Service status parsed: Success=True ===
# === [Recv Data] Camera Pose: Waiting for 56 bytes... ===
# === [Recv Data] Camera Pose: Received 56/56 bytes (100.0%) ===
# === [Recv Data] Camera Pose: Received complete! 56 bytes, cost 0.02 ms ===
# === [Parse Stream] 3. Camera pose parsed: ===
#   - Position (x,y,z): (-0.073548, -0.080167, 0.441255)
#   - Orientation (w,x,y,z): (0.999224, -0.020988, -0.024770, 0.022316)
# === [Recv Data] Camera Point Cloud Length: Waiting for 4 bytes... ===
# === [Recv Data] Camera Point Cloud Length: Received 4/4 bytes (100.0%) ===
# === [Recv Data] Camera Point Cloud Length: Received complete! 4 bytes, cost 0.02 ms ===
# === [Recv Data] Camera Point Cloud Data: Waiting for 1968 bytes... ===
# === [Recv Data] Camera Point Cloud Data: Received 1968/1968 bytes (100.0%) ===
# === [Recv Data] Camera Point Cloud Data: Received complete! 1968 bytes, cost 0.02 ms ===
# === [Parse Data] Camera Point Cloud: Starting parse (1968 bytes)... ===
# === [Parse Data] Camera Point Cloud: Parse completed! 164 points, NumPy shape: (164, 3) ===
# === [Parse Stream] 4. Camera point cloud parsed: 164 points ===
# === [Recv Data] World Point Cloud Length: Waiting for 4 bytes... ===
# === [Recv Data] World Point Cloud Length: Received 4/4 bytes (100.0%) ===
# === [Recv Data] World Point Cloud Length: Received complete! 4 bytes, cost 0.02 ms ===
# === [Recv Data] World Point Cloud Data: Waiting for 1968 bytes... ===
# === [Recv Data] World Point Cloud Data: Received 1968/1968 bytes (100.0%) ===
# === [Recv Data] World Point Cloud Data: Received complete! 1968 bytes, cost 0.02 ms ===
# === [Parse Data] World Point Cloud: Starting parse (1968 bytes)... ===
# === [Parse Data] World Point Cloud: Parse completed! 164 points, NumPy shape: (164, 3) ===
# === [Parse Stream] 5. World point cloud parsed: 164 points ===
# === [Recv Data] Image Length: Waiting for 4 bytes... ===
# === [Recv Data] Image Length: Received 4/4 bytes (100.0%) ===
# === [Recv Data] Image Length: Received complete! 4 bytes, cost 0.02 ms ===
# === [Recv Data] Image Data: Waiting for 76122 bytes... ===
# === [Recv Data] Image Data: Received 4096/76122 bytes (5.38%) ===
# === [Recv Data] Image Data: Received 8192/76122 bytes (10.76%) ===
# === [Recv Data] Image Data: Received 12288/76122 bytes (16.14%) ===
# === [Recv Data] Image Data: Received 16384/76122 bytes (21.52%) ===
# === [Recv Data] Image Data: Received 20480/76122 bytes (26.9%) ===
# === [Recv Data] Image Data: Received 24576/76122 bytes (32.29%) ===
# === [Recv Data] Image Data: Received 28672/76122 bytes (37.67%) ===
# === [Recv Data] Image Data: Received 32768/76122 bytes (43.05%) ===
# === [Recv Data] Image Data: Received 36864/76122 bytes (48.43%) ===
# === [Recv Data] Image Data: Received 40960/76122 bytes (53.81%) ===
# === [Recv Data] Image Data: Received 45056/76122 bytes (59.19%) ===
# === [Recv Data] Image Data: Received 49152/76122 bytes (64.57%) ===
# === [Recv Data] Image Data: Received 53248/76122 bytes (69.95%) ===
# === [Recv Data] Image Data: Received 57344/76122 bytes (75.33%) ===
# === [Recv Data] Image Data: Received 61440/76122 bytes (80.71%) ===
# === [Recv Data] Image Data: Received 65536/76122 bytes (86.09%) ===
# === [Recv Data] Image Data: Received 69632/76122 bytes (91.47%) ===
# === [Recv Data] Image Data: Received 73728/76122 bytes (96.86%) ===
# === [Recv Data] Image Data: Received 76122/76122 bytes (100.0%) ===
# === [Recv Data] Image Data: Received complete! 76122 bytes, cost 0.86 ms ===
# === [Parse Stream] 6. Image parsed: 76122 bytes, shape: (480, 640, 3) ===
# === [Parse Stream] Parsing completed! Total received: 80159 bytes, cost 47.85 ms ===
#
# ============================================================
# === Final Parsed Results ===
# ============================================================
#
# --- Camera Intrinsics ---
# fx: 503.640273
# fy: 502.167721
# cx: 312.565456
# cy: 244.436855
#
# --- Service Status ---
# Success: True
#
# --- Camera Pose ---
# Position (x,y,z): (-0.073548, -0.080167, 0.441255)
# Orientation (w,x,y,z): (0.999224, -0.020988, -0.024770, 0.022316)
#
# --- Point Cloud (Camera Coordinate) ---
# Total Bytes: 1968, Point Count: 164
# Point Cloud NumPy Shape: (164, 3)
# First 5 Points (x:像素x, y:像素y, z:相机深度):
# [[ 68.08045    193.4918       0.43623206]
#  [193.4918     114.66181      1.3243228 ]
#  [315.31998    118.244995     1.2571975 ]
#  [ 89.579544   118.244995     1.128267  ]
#  [164.82635    114.66181      1.0269133 ]]
#
# --- Point Cloud (World Coordinate) ---
# Total Bytes: 1968, Point Count: 164
# Point Cloud NumPy Shape: (164, 3)
# First 5 Points (x:世界X, y:世界Y, z:世界Z):
# [[-0.30120584 -0.11535293  0.86834216]
#  [-0.4402849  -0.37676126  1.7619771 ]
#  [-0.11859134 -0.33036086  1.7090707 ]
#  [-0.60718334 -0.33541495  1.5553794 ]
#  [-0.40870756 -0.31561106  1.4630328 ]]
#
# --- Image Info ---
# Total Bytes: 76122, Image Shape: (480, 640, 3)
#
# --- Image Saved Successfully ---
# Image saved to: image_20260111_213826.jpg
#
# === [Client] Connection closed ===
